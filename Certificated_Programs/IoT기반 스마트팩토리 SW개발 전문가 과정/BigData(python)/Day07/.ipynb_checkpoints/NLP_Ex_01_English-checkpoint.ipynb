# %% [markdown]
# 영문분석 데이터 Load

# %%
import pandas as pd
import glob
import re
from functools import reduce
from nltk.tokenize import word_tokenize,WordPunctTokenizer  
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import STOPWORDS, WordCloud

# %% [markdown]
# 데이터 로드 및 병합

# %%
all_files = glob.glob('./RISS_Excel/myCabinetExcelData*.xls')

all_files_data = []
for file in all_files:
    data_frame = pd.read_excel(file)
    all_files_data.append(data_frame)
all_files_data[0]

all_files_data_concat = pd.concat(all_files_data,axis=0, ignore_index=True)

# %% [markdown]
# 제목만 뽑아내기

# %%
all_title = all_files_data_concat['제목']
all_title
# Out:
# 0      Agile Big Data Analytics for Web-Based Systems...
# 1      A big data analytics framework for border cros...
# 2             Guest Editorial: Big Data Infrastructure I
# 3        Guest Editorial: Big Data Analytics and the Web
# 4      Guest Editorial: Big Scholar Data Discovery an...
#                              ...
# 995    A big data-based RF localisation method for un...
# 996                          Scalable big data modelling
# 997    Health big data analytics: current perspective...
# 998    Analyzing Big Smart Metering Data Towards Diff...
# 999              Intelligent big data analysis: a review
# Name: 제목, Length: 1000, dtype: object

# %% [markdown]
# 데이터 전처리
# - stopwrod 불러오기
# - 만약 에러 발생시 :
# ```python
# import nltk
# nltk.download('stopwords')
# ```

# %%
stopWords = set(stopwords.words('english'))
lemma = WordNetLemmatizer()

# %% [markdown]
# 데이터 전처리
# - 단어 단위로 자르기
# - 에러발생시
# ```python
# import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
# ```
#
# ``` python
# words = []
# for title in all_title:
#     EnWords = re.sub(r"[^a-zA-Z]+",' ',str(title))       # 알파벳을 제외한 나머지를 공백으로 치환
#     EnWordsToken = word_tokenize(EnWords.lower())        # 소문자로 통일 후 단어별로 자름
#     EnWordsTokenStop = [ w for w in EnWordsToken if w not in stopWords]   # 자른단어가 종료문자에 있지않으면 리스트에 추가
#     EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]   # 표제어 추출
#     words.append(EnWordsTokenStopLemma)
# print(words)
# ```

# %%
words = []
for title in all_title:
    EnWords = re.sub(r"[^a-zA-Z]+",' ',str(title))
    EnWordsToken = word_tokenize(EnWords.lower())
    EnWordsTokenStop = [ w for w in EnWordsToken if w not in stopWords]
    EnWordsTokenStopLemma = [lemma.lemmatize(w) for w in EnWordsTokenStop]
    words.append(EnWordsTokenStopLemma)
print(words)
# Out:
# [['agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach'], ['big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation'], ['guest', 'editorial', 'big', 'data', 'infrastructure'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['guest', 'editorial', 'big', 'data', 'analytics', 'web'], ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'part'], ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining'], ['guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration'], ['architecting', 'time', 'critical', 'big', 'data', 'system'], ['guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining'], ['speed', 'big', 'data', 'analytics', 'unveiling', 'storage', 'distribution', 'sub', 'datasets'], ['five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics'], ['fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark'], ['smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data'], ['fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment'], ['secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data'], ['hierarchical', 'distributed', 'processing', 'framework', 'big', 'image', 'data'], ['hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data'], ['corporate', 'governance', 'fraud', 'detection', 'annual', 'report', 'using', 'big', 'data', 'analytics'], ['online', 'similarity', 'learning', 'big', 'data', 'overfitting'], ['towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud'], ['deduplication', 'encrypted', 'big', 'data', 'cloud'], ['enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data'], ['index', 'ieee', 'transaction', 'big', 'data', 'vol'], ['survey', 'big', 'data', 'processing', 'infrastructure', 'evolving', 'role', 'fpga'], ['hdm', 'composable', 'framework', 'big', 'data', 'processing'], ['classification', 'comparison', 'nosql', 'big', 'data', 'model'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'application'], ['guest', 'editorial', 'special', 'issue', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'continued'], ['computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow'], ['optimized', 'deep', 'learning', 'eeg', 'big', 'data', 'seizure', 'prediction', 'bci', 'via', 'internet', 'thing'], ['platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system'], ['structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data'], ['taxi', 'passenger', 'demand', 'modeling', 'based', 'big', 'data', 'roving', 'sensor', 'network'], ['availability', 'modelling', 'assurance', 'big', 'data', 'computing'], ['distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis'], ['nosql', 'database', 'big', 'data'], ['algorithmseer', 'system', 'extracting', 'searching', 'algorithm', 'scholarly', 'big', 'data'], ['dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data'], ['privacy', 'model', 'big', 'data', 'survey'], ['large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation'], ['kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework'], ['concentric', 'framework', 'leveraging', 'big', 'data', 'business', 'value'], ['toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system'], [ ...

# %%
words2 = list(reduce(lambda x,y : x+y, words))
print(words2)
# Out:
# ['agile', 'big', 'data', 'analytics', 'web', 'based', 'system', 'architecture', 'centric', 'approach', 'big', 'data', 'analytics', 'framework', 'border', 'crossing', 'transportation', 'guest', 'editorial', 'big', 'data', 'infrastructure', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'guest', 'editorial', 'big', 'data', 'analytics', 'web', 'guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'part', 'guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'guest', 'editorial', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'architecting', 'time', 'critical', 'big', 'data', 'system', 'guest', 'editorial', 'big', 'medium', 'data', 'understanding', 'search', 'mining', 'speed', 'big', 'data', 'analytics', 'unveiling', 'storage', 'distribution', 'sub', 'datasets', 'five', 'layer', 'architecture', 'big', 'data', 'processing', 'analytics', 'fuzzy', 'based', 'scalable', 'clustering', 'algorithm', 'handling', 'big', 'data', 'using', 'apache', 'spark', 'smart', 'monitoring', 'camera', 'driven', 'intelligent', 'processing', 'big', 'surveillance', 'video', 'data', 'fast', 'approach', 'semantic', 'service', 'composition', 'big', 'data', 'environment', 'secure', 'multi', 'owner', 'based', 'cloud', 'computing', 'scheme', 'big', 'data', 'hierarchical', 'distributed', 'processing', 'framework', 'big', 'image', 'data', 'hybridisation', 'classifier', 'anomaly', 'detection', 'big', 'data', 'corporate', 'governance', 'fraud', 'detection', 'annual', 'report', 'using', 'big', 'data', 'analytics', 'online', 'similarity', 'learning', 'big', 'data', 'overfitting', 'towards', 'max', 'min', 'fair', 'resource', 'allocation', 'stream', 'big', 'data', 'analytics', 'shared', 'cloud', 'deduplication', 'encrypted', 'big', 'data', 'cloud', 'enhanced', 'visualization', 'method', 'aid', 'behavioral', 'trajectory', 'pattern', 'recognition', 'infrastructure', 'big', 'longitudinal', 'data', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'survey', 'big', 'data', 'processing', 'infrastructure', 'evolving', 'role', 'fpga', 'hdm', 'composable', 'framework', 'big', 'data', 'processing', 'classification', 'comparison', 'nosql', 'big', 'data', 'model', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'special', 'issue', 'biomedical', 'big', 'data', 'understanding', 'learning', 'application', 'guest', 'editorial', 'special', 'issue', 'big', 'scholar', 'data', 'discovery', 'collaboration', 'continued', 'computation', 'migration', 'new', 'approach', 'execute', 'big', 'data', 'bioinformatics', 'workflow', 'optimized', 'deep', 'learning', 'eeg', 'big', 'data', 'seizure', 'prediction', 'bci', 'via', 'internet', 'thing', 'platform', 'big', 'data', 'analytics', 'distributed', 'scale', 'storage', 'system', 'structural', 'balance', 'theory', 'based', 'e', 'commerce', 'recommendation', 'big', 'rating', 'data', 'taxi', 'passenger', 'demand', 'modeling', 'based', 'big', 'data', 'roving', 'sensor', 'network', 'availability', 'modelling', 'assurance', 'big', 'data', 'computing', 'distributed', 'feature', 'selection', 'efficient', 'economic', 'big', 'data', 'analysis', 'nosql', 'database', 'big', 'data', 'algorithmseer', 'system', 'extracting', 'searching', 'algorithm', 'scholarly', 'big', 'data', 'dip', 'svm', 'distribution', 'preserving', 'kernel', 'support', 'vector', 'machine', 'big', 'data', 'privacy', 'model', 'big', 'data', 'survey', 'large', 'scale', 'spectral', 'clustering', 'managing', 'big', 'data', 'healthcare', 'operation', 'kvasir', 'scalable', 'provision', 'semantically', 'relevant', 'web', 'content', 'big', 'data', 'framework', 'concentric', 'framework', 'leveraging', 'big', 'data', 'business', 'value', 'toward', 'efficient', 'flexible', 'metadata', 'indexing', 'big', 'data', 'system', 'index', 'ieee', 'transaction', 'big', 'data', 'vol', 'towards', 'quality', 'service', 'drive ...

# %% [markdown]
# 단어 빈도 구하기

# %%
count = Counter(words2)
count
# Out:
# Counter({'agile': 1,
#          'big': 1346,
#          'data': 1617,
#          'analytics': 134,
#          'web': 9,
#          'based': 64,
#          'system': 48,
#          'architecture': 12,
#          'centric': 2,
#          'approach': 43,
#          'framework': 28,
#          'border': 1,
#          'crossing': 1,
#          'transportation': 4,
#          'guest': 10,
#          'editorial': 13,
#          'infrastructure': 11,
#          'scholar': 3,
#          'discovery': 14,
#          'collaboration': 5,
#          'medium': 13,
#          'understanding': 11,
#          'search': 7,
#          'mining': 37,
#          'part': 1,
#          'architecting': 2,
#          'time': 18,
#          'critical': 4,
#          'speed': 1,
#          'unveiling': 1,
#          'storage': 22,
#          'distribution': 7,
#          'sub': 1,
#          'datasets': 5,
#          'five': 4,
#          'layer': 1,
#          'processing': 29,
#          'fuzzy': 2,
#          'scalable': 12,
#          'clustering': 8,
#          'algorithm': 16,
#          'handling': 6,
#          'using': 54,
#          'apache': 5,
#          'spark': 4,
#          'smart': 33,
#          'monitoring': 8,
#          'camera': 1,
#          'driven': 31,
#          'intelligent': 6,
#          'surveillance': 2,
#          'video': 2,
#          'fast': 4,
#          'semantic': 6,
#          'service': 25,
#          'composition': 1,
#          'environment': 14,
#          'secure': 2,
#          'multi': 11,
#          'owner': 1,
#          'cloud': 30,
#          'computing': 22,
#          'scheme': 3,
#          'hierarchical': 1,
#          'distributed': 19,
#          'image': 5,
#          'hybridisation': 1,
#          'classifier': 1,
#          'anomaly': 2,
#          'detection': 5,
#          'corporate': 2,
#          'governance': 5,
#          'fraud': 6,
#          'annual': 2,
#          'report': 7,
#          'online': 7,
#          'similarity': 2,
#          'learning': 33,
#          'overfitting': 1,
#          'towards': 12,
#          'max': 1,
#          'min': 1,
#          'fair': 2,
#          'resource': 5,
#          'allocation': 3,
#          'stream': 9,
#          'shared': 2,
#          'deduplication': 2,
#          'encrypted': 1,
#          'enhanced': 2,
#          'visualization': 7,
#          'method': 18,
#          'aid': 1,
#          'behavioral': 3,
#          'trajectory': 3,
#          'pattern': 3,
#          'recognition': 1,
#          'longitudinal': 4,
#          'index': 4,
#          'ieee': 2,
#          'transaction': 2,
#          'vol': 2,
#          'survey': 20,
#          'evolving': 3,
#          'role': 9,
#          'fpga': 1,
#          'hdm': 1,
#          'composable': 1,
#          'classification': 7,
#          'comparison': 2,
#          'nosql': 3,
#          'model': 44,
#          'platform': 20,
#          'scale': 12,
#          'special': 11,
#          'issue': 23,
#          'biomedical': 2,
#          'application': 22,
#          'continued': 1,
#          'computation': 3,
#          'migration': 3,
#          'new': 32,
#          'execute': 1,
#          'bioinformatics': 2,
#          'workflow': 3,
#          'optimized': 2,
#          'deep': 8,
#          'eeg': 1,
#          'seizure': 2,
#          'prediction': 14,
#          'bci': 1,
#          'via': 5,
#          'internet': 7,
#          'thing': 10,
#          'structural': 3,
#          'balance': 1,
#          'theory': 6,
#          'e': 8,
#          'commerce': 3,
#          'recommendation': 2,
#          'rating': 2,
#          'taxi': 1,
#          'passenger': 1,
#          'demand': 4,
#          'modeling': 11,
#          'roving': 1,
#          'sensor': 6,
#          'network': 20,
#          'availability': 1,
#          'modelling': 4,
#          'assurance': 3,
#          'feature': 2,
#          'selection': 4,
#          'efficient': 21,
#          'economic': 2,
#          'analysis': 73,
#          'database': 9,
#          'algorithmseer': 1,
#          'extracting': 3,
#          'searching': 1,
#          'scholarly': 4,
#          'dip': 1,
#          'svm': 1,
#          'preserving': 3,
#          'kernel': 3,
#          'support': 11,
#          'vector': 2,
#          'machine': 17,
#          'privacy': 21,
#          'large': 17,
#          'spectral': 2,
#          'managing': 3,
#          'healthcare': 19,
#          'operation': 8,
#          'kvasir': 1,
#          'provision': 1,
#          'semantically': 2,
#          'relevant': 1,
#          'content': 3,
#          'concentric': 1,
#          'leveraging': 8,
#          'business': 22,
#          'value': 12,
#          'toward': 7,
#          'flexible': 2,
#          'metadata': 4,
#          'indexing': 2,
#          'quality': 23,
#          'consistency': 2,
#          'management': 52,
#          'real': 14,
#          'health': 33,
#          'palopro': 1,
#          'knowledge': 21,
#          'extraction': 4,
#          'social': 17,
#          'news': 3,
#          'perception': 2,
#          'independent': 3,
#          'financial': 7,
#          'advisor': 1,
#          'usefulness': 1,
#          'context': 11,
#          'decision': 19,
#          'making': 19,
#          'uk': 2,
#          'development': 8,
#          'aware': 11,
#          'parallel': 3,
#          'k': 7,
#          'anonymisation': 1,
#          'petuum': 1,
#          'extended': 3,
#          'spatio': 3,
#          'temporal': 4,
#          'granger': 1,
#          'causality': 2,
#          'air': 3,
#          'estimation': 2,
#          'heterogeneous': 6,
#          'urban': 8,
#          'accurate': 3,
#          'cluster': 2,
#          'competitive': 6,
#          'mean': 10,
#          'review': 22,
#          'ethical': 2,
#          'concern': 6,
#          'current': 7,
#          'trend': 7,
#          'predictive': 15,
#          'archeological': 1,
#          'recovery': 3,
#          'site': 2,
#          'b': 3,
#          'year': 4,
#          'old': 2,
#          'chisos': 1,
#          'basin': 1,
#          'bend': 1,
#          'national': 5,
#          'park': 1,
#          'always': 3,
#          'yield': 2,
#          'benefit': 8,
#          'improves': 1,
#          'care': 16,
#          'academic': 4,
#          'librarian': 5,
#          'competency': 1,
#          'skill': 2,
#          'implementation': 1,
#          'library': 2,
#          'discretization': 1,
#          'taxonomy': 2,
#          'challenge': 43,
#          'applying': 5,
#          'kansei': 1,
#          'engineering': 4,
#          'hotel': 2,
#          'bayesian': 4,
#          'perspective': 21,
#          'done': 2,
#          'first': 5,
#          'international': 6,
#          'conference': 4,
#          'bigcomp': 1,
#          'entity': 1,
#          'graph': 8,
#          'communication': 4,
#          'bigger': 7,
#          'biggest': 6,
#          'repository': 3,
#          'balloon': 1,
#          'unprecedented': 1,
#          'level': 7,
#          'coping': 2,
#          'security': 14,
#          'criminal': 1,
#          'investigation': 1,
#          'swarm': 1,
#          'intelligence': 11,
#          'dimension': 4,
#          'distrubted': 1,
#          'warehouse': 18,
#          'dws': 2,
#          'technique': 7,
#          'insight': 15,
#          'mapreduce': 7,
#          'programming': 1,
#          'enabled': 6,
#          'cyber': 1,
#          'physical': 3,
#          'small': 24,
#          'enterprise': 7,
#          'sector': 10,
#          'paradigm': 2,
#          'status': 1,
#          'revised': 1,
#          'pyramid': 1,
#          'improving': 3,
#          'map': 6,
#          'shuffle': 1,
#          'phase': 3,
#          'hadoop': 5,
#          'reduce': 1,
#          'technology': 29,
#          'process': 16,
#          'spatial': 10,
#          'attribute': 1,
#          'designing': 2,
#          'operating': 2,
#          'mine': 2,
#          'assessment': 5,
#          'peer': 1,
#          'produced': 1,
#          'case': 11,
#          'implicit': 2,
#          'wikipedia': 1,
#          'fusion': 3,
#          'result': 4,
#          'output': 1,
#          'memory': 6,
#          'partner': 1,
#          'allina': 1,
#          'team': 3,
#          'catalyst': 2,
#          'garner': 1,
#          'michael': 3,
#          'buck': 4,
#          'talk': 1,
#          'living': 1,
#          'dream': 2,
#          'bioinformaticist': 1,
#          'emerging': 8,
#          'alternative': 3,
#          'practical': 6,
#          'eu': 4,
#          'law': 12,
#          'face': 4,
#          'shake': 2,
#          'automated': 4,
#          'slicing': 1,
#          'validation': 1,
#          'ai': 4,
#          'integration': 6,
#          'tensor': 2,
#          'dimensionality': 1,
#          'reduction': 3,
#          'problem': 15,
#          'grid': 6,
#          'sdn': 3,
#          'geographical': 1,
#          'condition': 2,
#          'linked': 2,
#          'coal': 1,
#          'fired': 1,
#          'power': 5,
#          'plant': 4,
#          'exploring': 5,
#          'fundamental': 1,
#          'scientific': 5,
#          'build': 2,
#          'better': 3,
#          'em': 3,
#          'forecasting': 4,
#          'source': 10,
#          'recursive': 1,
#          'approximation': 2,
#          'error': 3,
#          'sensing': 8,
#          'rule': 2,
#          'granularity': 1,
#          'semantics': 5,
#          'mongodb': 1,
#          'modular': 1,
#          'ontology': 3,
#          'building': 9,
#          'cell': 1,
#          'phone': 1,
#          'compute': 2,
#          'mobility': 2,
#          'scenario': 2,
#          'future': 15,
#          'city': 17,
#          'heavy': 2,
#          'tailed': 1,
#          'meet': 10,
#          'formal': 1,
#          'novel': 4,
#          'china': 5,
#          'deal': 18,
#          'detailed': 2,
#          'prominent': 1,
#          'compression': 3,
#          'used': 4,
#          'reducing': 1,
#          'volume': 5,
#          'advanced': 7,
#          'chunk': 1,
#          'updating': 2,
#          'correct': 1,
#          'measurement': 7,
#          'hyper': 1,
#          'convergent': 1,
#          'regional': 3,
#          'innovation': 9,
#          'holistic': 1,
#          'view': 4,
#          'skyline': 1,
#          'mr': 1,
#          'plot': 1,
#          'tool': 9,
#          'distinguishing': 1,
#          'comprehensive': 5,
#          'incremental': 3,
#          'query': 6,
#          'sentiment': 5,
#          'educational': 2,
#          'evaluating': 2,
#          'effect': 3,
#          'global': 5,
#          'emulated': 1,
#          'order': 3,
#          'identification': 2,
#          'series': 3,
#          'design': 13,
#          'methodology': 4,
#          'quantile': 1,
#          'regression': 2,
#          'divide': 4,
#          'conquer': 3,
#          'strategy': 11,
#          'organisation': 2,
#          'leverage': 4,
#          'maturity': 1,
#          'barrier': 2,
#          'embedding': 1,
#          'solution': 10,
#          'factory': 5,
#          'sap': 1,
#          'consultant': 1,
#          'watchdog': 1,
#          'name': 1,
#          'matching': 1,
#          'risk': 12,
#          'overview': 4,
#          'sharing': 13,
#          'analyzing': 6,
#          'electrophysiology': 1,
#          'supervised': 2,
#          'dataset': 1,
#          'sensory': 1,
#          'wireless': 4,
#          'advancing': 2,
#          'science': 47,
#          'stakeholder': 2,
#          'word': 1,
#          'mouth': 1,
#          'csr': 1,
#          'dynamic': 5,
#          'twitter': 4,
#          'simd': 1,
#          'mcmc': 1,
#          'sampling': 4,
#          'predicting': 1,
#          'amazon': 1,
#          'product': 7,
#          'effective': 5,
#          'clinical': 7,
#          'vecchia': 1,
#          'laplace': 1,
#          'generalized': 3,
#          'gaussian': 2,
#          'non': 2,
#          'comparing': 1,
#          'world': 16,
#          'sustainable': 5,
#          'supply': 8,
#          'chain': 10,
#          'finance': 2,
#          'bibliometric': 2,
#          'retail': 1,
#          'apriori': 1,
#          'analysing': 1,
#          'repeat': 1,
#          'blood': 1,
#          'donation': 1,
#          'behavior': 4,
#          'subdata': 1,
#          'pipeline': 3,
#          'broadcasting': 1,
#          'feasibility': 1,
#          'implication': 5,
#          'era': 20,
#          'haery': 1,
#          'accumulative': 1,
#          'high': 8,
#          'dimensional': 1,
#          'semi': 1,
#          'automatic': 2,
#          'transforming': 3,
#          'fact': 3,
#          'suspicious': 1,
#          'tax': 1,
#          'evasion': 1,
#          'group': 2,
#          'canonical': 1,
#          'correlation': 2,
#          'multiview': 1,
#          'bias': 3,
#          'correction': 3,
#          'sample': 4,
#          'skia': 1,
#          'textual': 1,
#          'pcce': 1,
#          'personality': 1,
#          'communicative': 1,
#          'community': 3,
#          'stock': 3,
#          'market': 16,
#          'direction': 1,
#          'uncertainty': 3,
#          'measure': 5,
#          'conflict': 1,
#          'evidence': 5,
#          'dempster': 1,
#          'shafer': 1,
#          'gamma': 1,
#          'matrix': 1,
#          'summarize': 1,
#          'dense': 1,
#          'sparse': 3,
#          'set': 8,
#          'nearest': 3,
#          'neighbour': 1,
#          'join': 4,
#          'theoretical': 2,
#          'experimental': 3,
#          'neighbor': 2,
#          'v': 3,
#          'simple': 2,
#          'pre': 5,
#          'step': 3,
#          'nonlinear': 1,
#          'va': 1,
#          'store': 5,
#          'virtual': 2,
#          'approximate': 2,
#          'supporting': 3,
#          'repetitive': 1,
#          'genome': 1,
#          'sequence': 2,
#          'government': 5,
#          'legal': 8,
#          'question': 12,
#          'stay': 2,
#          'ip': 1,
#          'todd': 1,
#          'vare': 1,
#          'mattioli': 1,
#          'look': 3,
#          'protected': 1,
#          'u': 10,
#          'ask': 1,
#          'whether': 2,
#          'thrive': 1,
#          'existing': 1,
#          'concept': 5,
#          'hard': 2,
#          'quantify': 1,
#          'good': 6,
#          'remember': 1,
#          'hat': 1,
#          'made': 3,
#          'work': 6,
#          'school': 2,
#          'company': 13,
#          'sears': 1,
#          'trying': 1,
#          'bang': 6,
#          'iron': 2,
#          'fifteen': 1,
#          'cosmic': 1,
#          'microwave': 1,
#          'background': 1,
#          'nersc': 1,
#          'addressing': 2,
#          'energy': 12,
#          'amp': 8,
#          'p': 4,
#          'industry': 13,
#          'must': 3,
#          'growing': 4,
#          'population': 3,
#          'gain': 7,
#          'link': 1,
#          'money': 8,
#          'make': 5,
#          'major': 2,
#          'difference': 1,
#          'even': 1,
#          'spinning': 1,
#          'impact': 11,
#          'four': 4,
#          'computerworld': 1,
#          'honor': 1,
#          'laureate': 1,
#          'battle': 1,
#          'unemployment': 1,
#          'climate': 4,
#          'change': 11,
#          'raise': 2,
#          'awareness': 1,
#          'help': 8,
#          'student': 5,
#          'personalized': 2,
#          'job': 3,
#          'embrace': 1,
#          'strategist': 1,
#          'communicator': 1,
#          'chop': 1,
#          'snag': 1,
#          'provides': 4,
#          'lesson': 1,
#          'prevent': 2,
#          'becoming': 5,
#          'creating': 5,
#          'example': 4,
#          'use': 24,
#          'consequence': 6,
#          'pain': 4,
#          'lawyer': 3,
#          'huge': 2,
#          'quantity': 1,
#          'offer': 4,
#          'potential': 14,
#          'boon': 1,
#          'cause': 2,
#          'headache': 3,
#          'cognitive': 1,
#          'research': 36,
#          'really': 4,
#          'conceptual': 2,
#          'km': 1,
#          'competition': 1,
#          'hope': 3,
#          'hype': 6,
#          'early': 3,
#          'software': 5,
#          'defined': 3,
#          'networking': 2,
#          'digital': 9,
#          'administrative': 2,
#          'compared': 1,
#          'classical': 1,
#          'toolbox': 1,
#          'assessing': 3,
#          'exemplified': 1,
#          'generation': 6,
#          'corruption': 1,
#          'think': 1,
#          'identifying': 2,
#          'suitable': 1,
#          'snapshot': 1,
#          'latin': 2,
#          'america': 1,
#          'american': 1,
#          'country': 2,
#          'long': 3,
#          'way': 12,
#          'go': 2,
#          'develop': 2,
#          'politics': 3,
#          'brother': 10,
#          'r': 2,
#          'tnani': 1,
#          'schneidern': 1,
#          'green': 5,
#          'ed': 2,
#          'londonroutledge': 1,
#          'pp': 4,
#          'isbn': 4,
#          'finding': 6,
#          'space': 4,
#          'peril': 1,
#          'york': 2,
#          'kalvi': 1,
#          'human': 11,
#          'project': 7,
#          'aim': 2,
#          'resolving': 1,
#          'listen': 1,
#          'cmos': 1,
#          'turned': 1,
#          'action': 5,
#          'present': 3,
#          'unlimited': 1,
#          'opportunity': 28,
#          'marketer': 6,
#          'know': 6,
#          'interpreting': 1,
#          'auctioning': 1,
#          'correctly': 1,
#          'brand': 3,
#          'see': 4,
#          'consumer': 7,
#          'coming': 4,
#          'back': 2,
#          'implementing': 3,
#          'introduction': 7,
#          'open': 22,
#          'kind': 3,
#          'access': 7,
#          'researcher': 6,
#          'enjoy': 3,
#          'political': 5,
#          'sociology': 1,
#          'practice': 11,
#          'flying': 1,
#          'test': 3,
#          'simulation': 4,
#          'equivalent': 1,
#          'equipment': 2,
#          'efficiency': 5,
#          'evaluation': 4,
#          'bi': 3,
#          'hp': 1,
#          'fledgling': 1,
#          'warehousing': 5,
#          'get': 7,
#          'lift': 1,
#          'wal': 1,
#          'mart': 1,
#          'blue': 3,
#          'ibm': 1,
#          'plan': 3,
#          'cut': 2,
#          'centre': 6,
#          'consumption': 2,
#          'per': 1,
#          'cent': 1,
#          'say': 5,
#          'expert': 6,
#          'medical': 9,
#          'diagnosis': 3,
#          'patient': 13,
#          'complaint': 1,
#          'improve': 12,
#          'greening': 1,
#          'tracking': 2,
#          'remote': 6,
#          'worker': 1,
#          'employee': 5,
#          'fear': 2,
#          'may': 1,
#          'cross': 2,
#          'line': 4,
#          'serious': 2,
#          'reputation': 1,
#          'damage': 1,
#          'costly': 1,
#          'fine': 1,
#          'violation': 1,
#          'improved': 6,
#          'acquisition': 4,
#          'industrial': 3,
#          'methodological': 3,
#          'tourism': 2,
#          'book': 3,
#          'excerpt': 1,
#          'enabling': 1,
#          'differentiation': 1,
#          'meaning': 2,
#          'bringing': 1,
#          'chaos': 2,
#          'two': 3,
#          'decade': 1,
#          'general': 4,
#          'protection': 12,
#          'regulation': 3,
#          'month': 2,
#          'away': 1,
#          'already': 1,
#          'need': 11,
#          'getting': 1,
#          'head': 1,
#          'round': 1,
#          'heat': 2,
#          'treatment': 5,
#          'contribute': 1,
#          'treating': 1,
#          'adaptive': 3,
#          'flow': 6,
#          'transformation': 2,
#          'enriched': 2,
#          'simplified': 1,
#          'education': 8,
#          'savvy': 2,
#          'performance': 10,
#          'requires': 1,
#          'primary': 2,
#          'et': 3,
#          'quel': 2,
#          'acc': 2,
#          'pour': 2,
#          'la': 2,
#          'recherche': 2,
#          'mixed': 2,
#          'economy': 4,
#          'clean': 3,
#          'wie': 1,
#          'sieht': 1,
#          'die': 1,
#          'zukunft': 2,
#          'von': 2,
#          'labordaten': 1,
#          'au': 2,
#          'minimal': 1,
#          'delay': 1,
#          'guaranteed': 1,
#          'resolution': 3,
#          'disaster': 4,
#          'area': 2,
#          'course': 3,
#          'given': 1,
#          'expectation': 1,
#          'frame': 1,
#          'friendly': 1,
#          'brings': 1,
#          'home': 2,
#          'bacon': 1,
#          'invested': 1,
#          'creation': 5,
#          'derive': 2,
#          'information': 21,
#          'vehicle': 3,
#          'diagnostic': 1,
#          'pay': 3,
#          'illinois': 1,
#          'fabricator': 1,
#          'trial': 1,
#          'neural': 2,
#          'low': 2,
#          'latency': 1,
#          'iot': 8,
#          'edge': 5,
#          'next': 12,
#          'training': 5,
#          'artificial': 5,
#          'li': 2,
#          'ion': 4,
#          'prognosis': 2,
#          'olap': 1,
#          'state': 11,
#          'art': 1,
#          'idea': 6,
#          'president': 2,
#          'message': 4,
#          'panel': 2,
#          'sigdss': 1,
#          'icis': 1,
#          'swiss': 1,
#          'army': 2,
#          'knife': 1,
#          'profile': 3,
#          'scientist': 5,
#          'become': 2,
#          'increasingly': 1,
#          'essential': 1,
#          'success': 1,
#          'oil': 2,
#          'gas': 2,
#          'protect': 1,
#          'invention': 1,
#          'grows': 2,
#          'unstructured': 2,
#          'center': 12,
#          'trading': 1,
#          'served': 1,
#          'oracle': 1,
#          'hewlett': 1,
#          'packard': 1,
#          'appliance': 1,
#          'easy': 2,
#          'place': 2,
#          'young': 1,
#          'people': 4,
#          'rhetoric': 1,
#          'toronto': 1,
#          'semiconductor': 1,
#          'front': 1,
#          'lagging': 1,
#          'behind': 3,
#          'capital': 2,
#          'supplier': 1,
#          'provide': 2,
#          'analytical': 3,
#          'generated': 3,
#          'fab': 1,
#          'customer': 5,
#          'address': 2,
#          'investigating': 1,
#          'language': 1,
#          'specific': 1,
#          'driver': 1,
#          'satisfaction': 1,
#          'user': 5,
#          'preliminary': 1,
#          'easier': 1,
#          'stroke': 4,
#          'epidemiology': 4,
#          'united': 3,
#          'biology': 5,
#          'geophysical': 1,
#          'biological': 1,
#          'program': 2,
#          'term': 1,
#          'ecological': 1,
#          'lter': 1,
#          'consent': 2,
#          'anonymise': 2,
#          'diverse': 1,
#          'benchmark': 2,
#          'reveal': 2,
#          'optimization': 5,
#          'imperative': 1,
#          'membrane': 1,
#          'function': 2,
#          'moovit': 1,
#          'created': 1,
#          'waze': 1,
#          'public': 12,
#          'transit': 1,
#          'app': 1,
#          'beat': 1,
#          'congestion': 1,
#          'traceability': 1,
#          'study': 10,
#          'standard': 2,
#          'reference': 3,
#          'korea': 1,
#          'manufacturing': 9,
#          'recent': 4,
#          'advance': 4,
#          'telemetry': 1,
#          'becomes': 2,
#          'cheese': 1,
#          'foremost': 1,
#          'farm': 1,
#          'double': 1,
#          'production': 3,
#          'add': 2,
#          'historian': 1,
#          'scada': 1,
#          'hmi': 1,
#          'intensive': 3,
#          'unit': 2,
#          'closing': 1,
#          'loop': 1,
#          'progress': 2,
#          'private': 2,
#          'forum': 2,
#          'unintended': 1,
#          'trauma': 3,
#          'outcome': 6,
#          'autonomous': 1,
#          'resuscitation': 1,
#          'shiming': 1,
#          'yang': 1,
#          'mary': 2,
#          'njoku': 1,
#          'colin': 1,
#          'f': 3,
#          'mackenzie': 1,
#          'discus': 5,
#          'massive': 4,
#          'friend': 1,
#          'foe': 1,
#          'advertising': 2,
#          'advantage': 3,
#          'like': 1,
#          'mayo': 1,
#          'clinic': 1,
#          'intermountain': 1,
#          'turning': 6,
#          'outside': 1,
#          'firm': 2,
#          'boost': 4,
#          'capability': 3,
#          'revolution': 8,
#          'continues': 1,
#          'unleash': 2,
#          'ever': 1,
#          'upon': 1,
#          'cii': 1,
#          'ordnance': 1,
#          'harnessed': 1,
#          'precision': 4,
#          'medicine': 9,
#          ...})

# %% [markdown]
# 단어 빈도 상위 50개 중 길이가 한글자 보다 큰 단어들만 추출

# %%
word_count = dict()

for tag, counts in count.most_common(50):
    if(len(str(tag))>1):
        word_count[tag] = counts
        print( '%s : %d' %(tag,counts))
# Out:
# data : 1617
# big : 1346
# analytics : 134
# analysis : 73
# based : 64
# using : 54
# management : 52
# system : 48
# science : 47
# model : 44
# approach : 43
# challenge : 43
# mining : 37
# research : 36
# smart : 33
# learning : 33
# health : 33
# new : 32
# driven : 31
# cloud : 30
# processing : 29
# technology : 29
# framework : 28
# opportunity : 28
# service : 25
# small : 24
# use : 24
# issue : 23
# quality : 23
# storage : 22
# computing : 22
# application : 22
# business : 22
# review : 22
# open : 22
# earth : 22
# efficient : 21
# privacy : 21
# knowledge : 21
# perspective : 21
# information : 21
# survey : 20
# platform : 20
# network : 20
# era : 20
# distributed : 19
# healthcare : 19
# decision : 19
# making : 19
# time : 18

# %%
sorted_Keys = sorted(word_count, key = word_count.get, reverse=True)
sorted_values = sorted(word_count.values(), reverse=True)
plt.bar(range(len(word_count)), sorted_values, align='center')
plt.xticks(range(len(word_count)),list(sorted_Keys),rotation='85')
plt.show()

# %% [markdown]
# ###  결과 시각화
# 년도별 논문수 그래프 그리기

# %%
all_files_data_concat['doc_count'] = 0
summary_year = all_files_data_concat.groupby('출판일',as_index=False)['doc_count'].count()
summary_year
# Out:
#      출판일  doc_count
# 0   1994          2
# 1   1995          3
# 2   1996          2
# 3   1997          2
# 4   1998          4
# 5   1999          1
# 6   2000          1
# 7   2001          1
# 8   2002          4
# 9   2003          1
# 10  2004          3
# 11  2005          3
# 12  2007          2
# 13  2008          3
# 14  2009          1
# 15  2010          3
# 16  2011          7
# 17  2012         29
# 18  2013         78
# 19  2014        132
# 20  2015        102
# 21  2016        138
# 22  2017        150
# 23  2018        131
# 24  2019        102
# 25  2020         72
# 26  2021         23

# %%
plt.figure(figsize=(12,5))
plt.xlabel('year')
plt.ylabel('Doc-count')
plt.grid(True)
plt.plot(range(len(summary_year)),summary_year['doc_count'])
plt.xticks(range(len(summary_year)),[text for text in summary_year['출판일']])
plt.show()

# %% [markdown]
# 워드클라우드 그리기

# %%
stopwords = set(STOPWORDS)
wc = WordCloud(background_color='ivory',stopwords=stopwords,width=800,height=600)
cloud = wc.generate_from_frequencies(word_count)
plt.figure(figsize=(8,8))
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
cloud.to_file('bigdata_word_cloud.jpg')
