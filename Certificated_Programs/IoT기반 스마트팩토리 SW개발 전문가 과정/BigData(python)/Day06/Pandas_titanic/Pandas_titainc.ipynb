# %% [markdown]
# csv 읽어오기

# %%
import pandas as pd
titanic = pd.read_csv('./titanic_train.csv')
titanic
# Out:
#      pclass  survived                                     name     sex    age  \
# 0         2         1        Mellinger, Miss. Madeleine Violet  female  13.00
# 1         2         1                        Wells, Miss. Joan  female   4.00
# 2         2         1           Duran y More, Miss. Florentina  female  30.00
# 3         3         0                       Scanlan, Mr. James    male    NaN
# 4         3         1             Bradley, Miss. Bridget Delia  female  22.00
# ..      ...       ...                                      ...     ...    ...
# 911       3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female   0.17
# 912       3         0                        Guest, Mr. Robert    male    NaN
# 913       3         1                       Smyth, Miss. Julia  female    NaN
# 914       2         1                     Sincock, Miss. Maude  female  20.00
# 915       3         0            Bourke, Mrs. John (Catherine)  female  32.00
#
# ...

# %% [markdown]
# 나이들 모두 출력

# %%
titanic['age']
# Out:
# 0      13.00
# 1       4.00
# 2      30.00
# 3        NaN
# 4      22.00
#        ...
# 911     0.17
# 912      NaN
# 913      NaN
# 914    20.00
# 915    32.00
# Name: age, Length: 916, dtype: float64

# %% [markdown]
# 최고령 확인

# %%
titanic['age'].max()
# Out:
# 74.0

# %% [markdown]
# 대략적인 데이터들

# %%
titanic.describe()
# Out:
#            pclass    survived         age       sibsp       parch        fare  \
# count  916.000000  916.000000  741.000000  916.000000  916.000000  916.000000
# mean     2.292576    0.385371   30.231444    0.532751    0.371179   32.532050
# std      0.842576    0.486949   13.934240    1.125957    0.837508   47.416524
# min      1.000000    0.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000   21.000000    0.000000    0.000000    7.895800
# 50%      3.000000    0.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   39.000000    1.000000    0.000000   31.275000
# max      3.000000    1.000000   74.000000    8.000000    9.000000  512.329200
#
#              body
# count   85.000000
# mean   157.870588
# std     98.257653
# min      1.000000
# 25%     68.000000
# 50%    148.000000
# 75%    249.000000
# max    328.000000

# %% [markdown]
# 인덱스별 타입

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# csv에서 읽어오기

# %%
titanic = pd.read_csv('./titanic_train.csv',index_col=0)
titanic
# Out:
#         survived                                     name     sex    age  \
# pclass
# 2              1        Mellinger, Miss. Madeleine Violet  female  13.00
# 2              1                        Wells, Miss. Joan  female   4.00
# 2              1           Duran y More, Miss. Florentina  female  30.00
# 3              0                       Scanlan, Mr. James    male    NaN
# 3              1             Bradley, Miss. Bridget Delia  female  22.00
# ...          ...                                      ...     ...    ...
# 3              1  Dean, Miss. Elizabeth Gladys "Millvina"  female   0.17
# 3              0                        Guest, Mr. Robert    male    NaN
# 3              1                       Smyth, Miss. Julia  female    NaN
# 2              1                     Sincock, Miss. Maude  female  20.00
# 3              0            Bourke, Mrs. John (Catherine)  female  32.00
#
#         sibsp  parch         ticket     fare cabin embarked  body  \
# pclass
# ...

# %% [markdown]
# 상위 8개만 추출

# %%
titanic.head(8)
# Out:
#         survived                               name     sex   age  sibsp  \
# pclass
# 2              1  Mellinger, Miss. Madeleine Violet  female  13.0      0
# 2              1                  Wells, Miss. Joan  female   4.0      1
# 2              1     Duran y More, Miss. Florentina  female  30.0      1
# 3              0                 Scanlan, Mr. James    male   NaN      0
# 3              1       Bradley, Miss. Bridget Delia  female  22.0      0
# 3              0               Linehan, Mr. Michael    male   NaN      0
# 1              1     Francatelli, Miss. Laura Mabel  female  30.0      0
# 2              1           Quick, Miss. Phyllis May  female   2.0      1
#
#         parch         ticket     fare cabin embarked  body  \
# pclass
# 2           1         250644  19.5000   NaN        S   NaN
# 2           1          29103  23.0000   NaN        S   NaN
# 2           0  SC/PARIS 2148  13.8583   NaN        C   NaN
# ...

# %% [markdown]
# 엑셀로 저장

# %%
titanic.to_excel('titanicic.xlsx', sheet_name="passengers",index=False)

# %% [markdown]
# 나이만 확인

# %%
ages = titanic['age']
ages.head()
# Out:
# pclass
# 2    13.0
# 2     4.0
# 2    30.0
# 3     NaN
# 3    22.0
# Name: age, dtype: float64

# %% [markdown]
# 이름, 나이 성별만 확인

# %%
titanic[['name','age','sex']]
# Out:
#                                            name    age     sex
# pclass
# 2             Mellinger, Miss. Madeleine Violet  13.00  female
# 2                             Wells, Miss. Joan   4.00  female
# 2                Duran y More, Miss. Florentina  30.00  female
# 3                            Scanlan, Mr. James    NaN    male
# 3                  Bradley, Miss. Bridget Delia  22.00  female
# ...                                         ...    ...     ...
# 3       Dean, Miss. Elizabeth Gladys "Millvina"   0.17  female
# 3                             Guest, Mr. Robert    NaN    male
# 3                            Smyth, Miss. Julia    NaN  female
# 2                          Sincock, Miss. Maude  20.00  female
# 3                 Bourke, Mrs. John (Catherine)  32.00  female
#
# [916 rows x 3 columns]

# %% [markdown]
# 20세 이하 승객

# %%
below_20 = titanic[titanic['age']<20]
below_20.head()
# Out:
#         survived                               name     sex   age  sibsp  \
# pclass
# 2              1  Mellinger, Miss. Madeleine Violet  female  13.0      0
# 2              1                  Wells, Miss. Joan  female   4.0      1
# 2              1           Quick, Miss. Phyllis May  female   2.0      1
# 2              1        Wells, Master. Ralph Lester    male   2.0      1
# 1              0       Allison, Miss. Helen Loraine  female   2.0      1
#
#         parch  ticket    fare    cabin embarked  body  \
# pclass
# 2           1  250644   19.50      NaN        S   NaN
# 2           1   29103   23.00      NaN        S   NaN
# 2           1   26360   26.00      NaN        S   NaN
# 2           1   29103   23.00      NaN        S   NaN
# 1           2  113781  151.55  C22 C26        S   NaN
#
#                               home.dest
# pclass
# 2              England / Bennington, VT
# 2                  Cornwall / Akron, OH
# 2         Plymouth, Devon / Detroit, MI
# ...

# %%
titanic
# Out:
#         survived                                     name     sex    age  \
# pclass
# 2              1        Mellinger, Miss. Madeleine Violet  female  13.00
# 2              1                        Wells, Miss. Joan  female   4.00
# 2              1           Duran y More, Miss. Florentina  female  30.00
# 3              0                       Scanlan, Mr. James    male    NaN
# 3              1             Bradley, Miss. Bridget Delia  female  22.00
# ...          ...                                      ...     ...    ...
# 3              1  Dean, Miss. Elizabeth Gladys "Millvina"  female   0.17
# 3              0                        Guest, Mr. Robert    male    NaN
# 3              1                       Smyth, Miss. Julia  female    NaN
# 2              1                     Sincock, Miss. Maude  female  20.00
# 3              0            Bourke, Mrs. John (Catherine)  female  32.00
#
#         sibsp  parch         ticket     fare cabin embarked  body  \
# pclass
# ...

# %%
titanic = pd.read_csv('./titanic_train.csv')

# %% [markdown]
# 1,2등석에 탑승한 승객

# %%
titanic[titanic['pclass'].isin([1,2])]
# Out:
#      pclass  survived                                            name     sex  \
# 0         2         1               Mellinger, Miss. Madeleine Violet  female
# 1         2         1                               Wells, Miss. Joan  female
# 2         2         1                  Duran y More, Miss. Florentina  female
# 6         1         1                  Francatelli, Miss. Laura Mabel  female
# 7         2         1                        Quick, Miss. Phyllis May  female
# ..      ...       ...                                             ...     ...
# 903       2         1                            Ridsdale, Miss. Lucy  female
# 905       1         1    Widener, Mrs. George Dunton (Eleanor Elkins)  female
# 908       2         0          Yrois, Miss. Henriette ("Mrs Harbeck")  female
# 909       1         1  Spencer, Mrs. William Augustus (Marie Eugenie)  female
# 914       2         1                            Sincock, Miss. Maude  female
#
# ...

# %% [markdown]
# 20세 이하 승객의 이름

# %%
titanic.loc[titanic['age'] < 20,'name']
# Out:
# 0            Mellinger, Miss. Madeleine Violet
# 1                            Wells, Miss. Joan
# 7                     Quick, Miss. Phyllis May
# 10                 Wells, Master. Ralph Lester
# 12                Allison, Miss. Helen Loraine
#                         ...
# 885                Sage, Master. William Henry
# 886             Baclini, Miss. Marie Catherine
# 893                         Davies, Mr. Joseph
# 896                 Dorking, Mr. Edward Arthur
# 911    Dean, Miss. Elizabeth Gladys "Millvina"
# Name: name, Length: 144, dtype: object

# %% [markdown]
# 20 ~ 23번행 과 5번~6번째 열

# %%
titanic.loc[20:23, 'age':'sibsp']
# Out:
#       age  sibsp
# 20    NaN      0
# 21   0.75      2
# 22  33.00      0
# 23  26.00      1

# %% [markdown]
# 연령으로 정렬

# %%
titanic.sort_values(by='age').head()
# Out:
#      pclass  survived                                     name     sex   age  \
# 911       3         1  Dean, Miss. Elizabeth Gladys "Millvina"  female  0.17
# 301       3         0           Peacock, Master. Alfred Edward    male  0.75
# 21        3         1                   Baclini, Miss. Eugenie  female  0.75
# 850       3         1                Aks, Master. Philip Frank    male  0.83
# 338       3         0             Klasen, Miss. Gertrud Emilia  female  1.00
#
#      sibsp  parch              ticket     fare cabin embarked  body  \
# 911      1      2           C.A. 2315  20.5750   NaN        S   NaN
# 301      1      1  SOTON/O.Q. 3101315  13.7750   NaN        S   NaN
# 21       2      1                2666  19.2583   NaN        C   NaN
# 850      0      1              392091   9.3500   NaN        S   NaN
# 338      1      1              350405  12.1833   NaN        S   NaN
#
#                        home.dest
# 911   Devon, England Wichita, KS
# ...

# %% [markdown]
# 퍼스트 클래스와 연령으로 정렬

# %%
titanic.sort_values(by=['pclass','age'], ascending=False).head()
# Out:
#      pclass  survived                       name     sex   age  sibsp  parch  \
# 634       3         0        Svensson, Mr. Johan    male  74.0      0      0
# 735       3         0       Connors, Mr. Patrick    male  70.5      0      0
# 804       3         0           Duane, Mr. Frank    male  65.0      0      0
# 504       3         1     Turkula, Mrs. (Hedwig)  female  63.0      0      0
# 711       3         0  Nysveen, Mr. Johan Hansen    male  61.0      0      0
#
#      ticket    fare cabin embarked   body home.dest
# 634  347060  7.7750   NaN        S    NaN       NaN
# 735  370369  7.7500   NaN        Q  171.0       NaN
# 804  336439  7.7500   NaN        Q    NaN       NaN
# 504    4134  9.5875   NaN        S    NaN       NaN
# 711  345364  6.2375   NaN        S    NaN       NaN

# %% [markdown]
# 평균연령

# %%
titanic["age"].mean()
# Out:
# 30.23144399460189

# %% [markdown]
# 연령과 탑승권 요금의 중간 값

# %%
titanic[["age",'fare']].median()
# Out:
# age     28.0000
# fare    14.4542
# dtype: float64

# %% [markdown]
# 카테고리별로 그룹화된 통계

# %%
titanic[["sex","age"]].groupby('sex').mean()
# Out:
#               age
# sex
# female  29.590786
# male    30.620564

# %% [markdown]
# 성별 및 승객 등급 조합의 평균

# %%
titanic.groupby(['sex','pclass'])['fare'].mean()
# Out:
# sex     pclass
# female  1         107.572121
#         2          21.974888
#         3          15.284941
# male    1          63.391160
#         2          18.320281
#         3          12.855432
# Name: fare, dtype: float64

# %% [markdown]
# 각 승객 등급 의 수

# %%
titanic['pclass'].value_counts()
# Out:
# 3    498
# 1    230
# 2    188
# Name: pclass, dtype: int64

# %% [markdown]
# 피벗전 데이터 전처리

# %%
titanic.drop(['ticket','name','home.dest','body'], inplace=True, axis=1)
titanic.head()

# %% [markdown]
# 피벗 테이블에서 인데스를 활용하여 데이터 그룹화

# %%
table = pd.pivot_table(data=titanic, index=['sex'])
table.plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# 다중 인덱스 피봇

# %%
table = pd.pivot_table(data=titanic, index=['sex','pclass'])
table
# Out:
#                      age        fare     parch     sibsp  survived
# sex    pclass
# female 1       37.520408  107.572121  0.467290  0.542056  0.953271
#        2       28.828767   21.974888  0.573333  0.493333  0.880000
#        3       22.971743   15.284941  0.666667  0.784314  0.496732
# male   1       40.867925   63.391160  0.252033  0.365854  0.325203
#        2       30.485714   18.320281  0.203540  0.336283  0.141593
#        3       26.332320   12.855432  0.263768  0.550725  0.153623

# %% [markdown]
# 특징별 다른 집계 함수 사용

# %%
table = pd.pivot_table(data=titanic, index=['sex','pclass'],
                      aggfunc={'age':np.mean,'survived':np.sum})
table
# Out:
#                      age  survived
# sex    pclass
# female 1       37.520408       102
#        2       28.828767        66
#        3       22.971743        76
# male   1       40.867925        40
#        2       30.485714        16
#        3       26.332320        53

# %% [markdown]
# value 매개변수를 사용하여 특정한 데이터에 대한 집계

# %%
table = pd.pivot_table(data=titanic, index=['sex','pclass'], values=['survived'],
                      aggfunc=np.mean)
table.plot(kind='bar')
table
# Out:
#                survived
# sex    pclass
# female 1       0.953271
#        2       0.880000
#        3       0.496732
# male   1       0.325203
#        2       0.141593
#        3       0.153623

# %% [markdown]
# 데이터간의 관계 찾기

# %%
table = pd.pivot_table(data=titanic, index=['sex'], columns=['pclass'], values=['survived'],
                      aggfunc=np.sum)
table.plot(kind='bar')
table
# Out:
#        survived
# pclass        1   2   3
# sex
# female      102  66  76
# male         40  16  53
